# %%
from matplotlib.pyplot import imshow
from PIL import Image, ImageDraw
import numpy as np

# %matplotlib inline

# %% [markdown]
# ## Load Image

# %%
image = Image.open(f'C:/Users/Yukawa/AI/rainbow.jpg', 'r')

# %%
pixels = image.load()

# %%
pixels[5,6]
# Out:
# (57, 14, 23)

# %% [markdown]
# ## Helper Image Functions

# %%
def show_image(img):
    imshow(np.asarray(img))
    print(f"Size: {img.size}")

# %%
show_image(image)
# Out:
# Size: (1920, 1200)

# %%
def save_image(img, location=f'C:/Users/Yukawa/AI/rainbow_result.jpg'):
    img.save(location)

# %%
#save_image(image)

# %%
def draw_line(img, start_x=50,start_y=50,end_x=1750,end_y=1100,color=(255,255,255),width=10):
    draw = ImageDraw.Draw(img)
    draw.line((start_x,start_y, end_x, end_y), fill=color, width=width)

# %%
draw_line(image, start_x=0,start_y=0, end_x=1920, end_y=1199,width=1)
show_image(image)
save_image(image)
# Out:
# Size: (1920, 1200)

# %%
image.show()
